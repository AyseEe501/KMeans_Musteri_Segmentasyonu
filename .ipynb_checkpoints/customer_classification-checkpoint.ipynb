# %%
#öncelikle bizim için gerekli olan kütüphaneleri tanımlıyoruz

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Ardından verisetimizin bulunduğu yolu path değişkenine atıyoruz.
#Peşinden atadığımız değişken içerisindeki csv dosyasını pandas ile okuyarak df adında verisetinin tutulduğu bir dataframe aktarıyoruz

# %%
path="C:/Users/HP/Desktop/Yapay Zeka Kursu Çalışmaları/data/CC GENERAL.csv"
df=pd.read_csv(path)

# %%
#df içeriği aşağıda görülmektedir.Sırasıyla sütun adlarını açıklayalım.

# CUST_ID : Kredi Kartı Sahibinin Kimliği (Kategorik)
# BALANCE: Alışveriş yapmak için hesaplarında kalan bakiye tutarı
# BALANCE_FREQUENCY : Bakiye ne sıklıkta güncellenir, 0 ile 1 arası puan (1 = sık güncellenir, 0 = sık güncellenmez)
# PURCHASES : Hesaptan yapılan satın alma tutarı
# ONEOFF_PURCHASES : Tek seferde yapılan maksimum satın alma tutarı
# INSTALLMENTS_PURCHASES : Taksitli alışveriş tutarı
# CASH_ADVANCE : Kullanıcı tarafından peşin verilen nakit
# PURCHASES_FREQUENCY : Satın almaların ne sıklıkta yapıldığı, 0 ile 1 arasında puan (1 = sık satın alınan, 0 = sık satın alınmayan)
# ONEOFF_PURCHASES_FREQUENCY : Satın almaların tek seferde ne sıklıkta gerçekleştiği (1 = sık satın alınan, 0 = sık satın alınmayan)
# PURCHASES_INSTALLMENTS_FREQUENCY : Taksitli alışverişlerin ne sıklıkla yapıldığı (1 = sık yapılır, 0 = sık yapılmaz)
# CASH_ADVANCE_FREQUENCY : Peşin ödemenin ne sıklıkla yapıldığı
# CASH_ADVANCE_TRX : "Gelişmiş Nakit" ile Yapılan İşlem Sayısı
# PURCHASES_TRX : Yapılan satın alma işlemlerinin sayısı
# CREDIT_LIMIT : Kullanıcı için Kredi Kartı Limiti
# PAYMENTS : Kullanıcı tarafından yapılan Ödeme Tutarı
# MINIMUM_PAYMENTS : Kullanıcı tarafından yapılan minimum ödeme tutarı
# PRC_FULL_PAYMENT : Kullanıcı tarafından ödenen tam ödemenin yüzdesi
# TENURE : Kullanıcı için kredi kartı hizmetinin süresi

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %%
df.shape#veri seti 18 sütun 8950 satırdan oluşur
# Out:
# (8950, 18)

# %%
# dataframe hakkında fikir almak için df.info() kullanıyoruz ve  detaylı içeriğine bakıyoruz

#Buna göre elimizdeki verisetinde 3 değişken tipi bulunduğu net bir şekilde anlaşılmaktadır.Bunlar sırasıyla "object","float64" ve "int64" tür.
#Alt kısmında hepsinden kaç tane olduğuda mevcuttur.
#Bunun dışında  MINIMUM_PAYMENTS ve CREDIT_LIMIT içerisinde nan değerler olduğu görülmektedir.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
#Şimdi ise bütün değerlerin ortalamalarını,standart sapmalarıını,tekil olup olmamalarını vs. detaylı inceleyelim

# %%
df.describe(include = 'all').T #bütün sütunların detaylı dağılımını görelim.Transpozunu almamızın sebebi ise sütunları, satır yaparak daha net görebilmek adınadır
# Out:
#                                    count unique     top freq         mean  \
# CUST_ID                             8950   8950  C10001    1          NaN
# BALANCE                           8950.0    NaN     NaN  NaN  1564.474828
# BALANCE_FREQUENCY                 8950.0    NaN     NaN  NaN     0.877271
# PURCHASES                         8950.0    NaN     NaN  NaN  1003.204834
# ONEOFF_PURCHASES                  8950.0    NaN     NaN  NaN   592.437371
# INSTALLMENTS_PURCHASES            8950.0    NaN     NaN  NaN   411.067645
# CASH_ADVANCE                      8950.0    NaN     NaN  NaN   978.871112
# PURCHASES_FREQUENCY               8950.0    NaN     NaN  NaN     0.490351
# ONEOFF_PURCHASES_FREQUENCY        8950.0    NaN     NaN  NaN     0.202458
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0    NaN     NaN  NaN     0.364437
# CASH_ADVANCE_FREQUENCY            8950.0    NaN     NaN  NaN     0.135144
# CASH_ADVANCE_TRX                  8950.0    NaN     NaN  NaN     3.248827
# PURCHASES_TRX                     8950.0    NaN     NaN  NaN    14.709832
# CREDIT_LIMIT                      8949.0    NaN     NaN  NaN   4494.44945
# PAYMENTS                          8950.0    NaN     NaN  NaN  1733.143852
# MINIMUM_PAYMENTS                  8637.0    NaN     NaN  NaN   864.206542
# PRC_FULL_PAYMENT                  8950.0    NaN     NaN  NaN     0.153715
# TENURE                            8950.0    NaN     NaN  NaN    11.517318
#
#                                           std       min         25%  \
# CUST_ID                                   NaN       NaN         NaN
# BALANCE                           2081.531879       0.0  128.281915
# BALANCE_FREQUENCY                    0.236904       0.0    0.888889
# PURCHASES                         2136.634782       0.0      39.635
# ONEOFF_PURCHASES                  1659.887917       0.0         0.0
# INSTALLMENTS_PURCHASES             904.338115       0.0         0.0
# CASH_ADVANCE                      2097.163877       0.0         0.0
# PURCHASES_FREQUENCY                  0.401371       0.0    0.083333
# ONEOFF_PURCHASES_FREQUENCY           0.298336       0.0         0.0
# PURCHASES_INSTALLMENTS_FREQUENCY     0.397448       0.0         0.0
# CASH_ADVANCE_FREQUENCY               0.200121       0.0         0.0
# CASH_ADVANCE_TRX                     6.824647       0.0         0.0
# PURCHASES_TRX                       24.857649       0.0         1.0
# CREDIT_LIMIT                      3638.815725      50.0      1600.0
# PAYMENTS                          2895.063757       0.0  383.276166
# MINIMUM_PAYMENTS                  2372.446607  0.019163  169.123707
# PRC_FULL_PAYMENT                     0.292499       0.0         0.0
# TENURE                               1.338331       6.0        12.0
#
#                                          50%          75%          max
# CUST_ID                                  NaN          NaN          NaN
# BALANCE                           873.385231  2054.140036  19043.13856
# BALANCE_FREQUENCY                        1.0          1.0          1.0
# PURCHASES                             361.28      1110.13     49039.57
# ONEOFF_PURCHASES                        38.0      577.405     40761.25
# INSTALLMENTS_PURCHASES                  89.0     468.6375      22500.0
# CASH_ADVANCE                             0.0  1113.821139  47137.21176
# PURCHASES_FREQUENCY                      0.5     0.916667          1.0
# ONEOFF_PURCHASES_FREQUENCY          0.083333          0.3          1.0
# PURCHASES_INSTALLMENTS_FREQUENCY    0.166667         0.75          1.0
# CASH_ADVANCE_FREQUENCY                   0.0     0.222222          1.5
# CASH_ADVANCE_TRX                         0.0          4.0        123.0
# PURCHASES_TRX                            7.0         17.0        358.0
# CREDIT_LIMIT                          3000.0       6500.0      30000.0
# PAYMENTS                          856.901546  1901.134317  50721.48336
# MINIMUM_PAYMENTS                  312.343947   825.485459  76406.20752
# PRC_FULL_PAYMENT                         0.0     0.142857          1.0
# TENURE                                  12.0         12.0         12.0

# %%
#Bu noktada CUST_ID' nin unique bir sütun olduğunu daha detaylı görmüş olduk.
#Bunun dışında veriseti içerisindeki tekrarlayan değerlerin olup olmadığına da bakalım.
#Eğer tekrarlayan değerler varsa onları unique bir hale getirmemiz gerekmektedir.

# %%
df.duplicated().sum() #tekrar eden değer yokmuş
# Out:
# 0

# %%
df.isna().sum() #nan olan sütunları daha net gördük
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#Bunları kullanılacak modeli etkilememesi için ya fillna ile doldurmalıyız ya da sütunu kaldırmalıyız.Bizim için veri fazlalığı önemli olduğundan doldurmayı tercih ediyorum.

# %%
df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].median(),inplace=True) #Bunları median değerleriyle doldurmayı tercih ettim.
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
#yukarıda artık nan değer olmadığı görülmektedir

# %%
data=df.drop(["CUST_ID"],axis=1) #verisetimizdeki sütun dağılımlarını detaylı görmek için geçici bir data içinde unique değer içeren sütunu kaldırdık
                                 #Bunu yapmalıydık çünkü bizim unique sütununu temizleyerek sayısal değerleri kullanmamız gereklidir.

# %%
data.head(5)#data adındaki yeni dataframede CUST_ID olmadığı görülmektedir
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        312.343947          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
#Şimdi ise elimizdeki verilerin distplot ile  ayrı ayrı yoğunluklarına bakalım

# %%
i=1
plt.figure(figsize= (20,40))
for col in data.columns:
    plt.subplot(9,2,i)
        
    sns.distplot(data[col])
    
    i=i+1
plt.show()

# %%
#Şimdi ise herbirinin çarpıklığına bakıyoruz.
#- ler sola doğru + lar ise sağa doğru bir çarpıklık olduğunu gösteriyor.
#0 olan değerler normal olduğunun göstergesidir.

# %%
for col in data.columns:
    print(col)
    print({data[col].skew()})
# Out:
# BALANCE
# {2.393386042571806}
# BALANCE_FREQUENCY
# {-2.0232655185149078}
# PURCHASES
# {8.144269064554651}
# ONEOFF_PURCHASES
# {10.045082884700278}
# INSTALLMENTS_PURCHASES
# {7.299119908745641}
# CASH_ADVANCE
# {5.166609074074723}
# PURCHASES_FREQUENCY
# {0.06016423585803591}
# ONEOFF_PURCHASES_FREQUENCY
# {1.5356127835248519}
# PURCHASES_INSTALLMENTS_FREQUENCY
# {0.5092011649999882}
# CASH_ADVANCE_FREQUENCY
# {1.828686266477852}
# CASH_ADVANCE_TRX
# {5.721298203192298}
# PURCHASES_TRX
# {4.630655265932403}
# CREDIT_LIMIT
# {1.5226359501884323}
# PAYMENTS
# {5.907619794397562}
# MINIMUM_PAYMENTS
# {13.852446498665346}
# PRC_FULL_PAYMENT
# {1.942819940971858}
# TENURE
# {-2.9430172876199134}

# %%
#Çarpıklığı düzeltebilmek adına herbir sütunun karelerini alıyoruz

# %%
i=1
plt.figure(figsize=(20,40))
for col in data.columns:
    plt.subplot(9,2,i)
    data[col]= np.sqrt(data[col])
    sns.distplot(data[col])
    i=i+1
    
plt.show()

# %%
for col in data.columns:
    print(col)
    print({data[col].skew()})
# Out:
# BALANCE
# {0.829497857072557}
# BALANCE_FREQUENCY
# {-2.8194948567414535}
# PURCHASES
# {1.7307522561530275}
# ONEOFF_PURCHASES
# {2.129460280033642}
# INSTALLMENTS_PURCHASES
# {1.5469393842026964}
# CASH_ADVANCE
# {1.4861590004379295}
# PURCHASES_FREQUENCY
# {-0.4218717893673732}
# ONEOFF_PURCHASES_FREQUENCY
# {0.7246072093111359}
# PURCHASES_INSTALLMENTS_FREQUENCY
# {0.13040915275372258}
# CASH_ADVANCE_FREQUENCY
# {0.7069756991977079}
# CASH_ADVANCE_TRX
# {1.417779463874218}
# PURCHASES_TRX
# {1.1857567220241383}
# CREDIT_LIMIT
# {0.6810872973244644}
# PAYMENTS
# {1.9515351600398658}
# MINIMUM_PAYMENTS
# {3.875507926615941}
# PRC_FULL_PAYMENT
# {1.2972800159306526}
# TENURE
# {-3.064332127759308}

# %%
#Yukarıda da görüldüğü gibi çarpıklıklar daha da iyi duruma getirildi

# %%
#Aykırı değerler, örnek veri kümesinin genel modelinden farklı olan gözlemlerdir. 
#Wikipedia bunu 'diğer gözlemlerden uzak bir gözlem noktası' olarak tanımlıyor. 
#ML algoritmaları aykırı değerlerin varlığında iyi çalışmaz.
#Şimdi, verilen veri setimizin bir kutu grafiği kullanarak herhangi bir aykırı değer içerip içermediğini görelim.

# %%
plt.figure(figsize = (20,16))
Features = data.columns
for i in range(len(Features)):
    plt.subplot(6,3, i + 1)
    sns.boxplot(y = data[Features[i]], data = data)
    plt.title(f"Boxplot of {Features[i]}")
    plt.tight_layout()

# %%
#Aykırı Değerler, PURCHASES_FREQUENCY, PURCHASES_INSTALLMENTS_FREQUENCY dışındaki tüm alanlarda mevcuttur.

#Çeyreklerini ve çeyrekler arası aralığını (IQR) kullanarak her özellik için aykırı değerleri 
#Bir değer, (birinci çeyrek - 1.5 IQR) değerinden küçük veya (üçüncü çeyrek + 1.5 IQR) değerinden büyükse aykırı değer olarak kabul edilir.

# %%
features=data.columns
def outliers(df, features):
    """Count the number of outliers for each feature using the IQR"""
    num_outliers = []
    pct_outliers = []
    total_rows = []
    interquartile_range = []
    for i in features:
        Q1 = df[i].quantile(.25)
        Q3 = df[i].quantile(.65)
        IQR = Q3 - Q1
        outliers = len(df[(df[i] < (Q1-1.5*IQR)) | (df[i] > (Q3+1.5*IQR))])
        rows = len(df[i])
        pct = outliers/rows
        interquartile_range.append(IQR)
        num_outliers.append(outliers)
        pct_outliers.append(pct)
        total_rows.append(rows)
        
    count_outliers = pd.DataFrame({'Feature': features
                               , 'Num_Outliers': num_outliers
                                , 'Percent_Outliers': pct_outliers
                                , 'IQR': interquartile_range
                               , 'Total_Rows': total_rows}).sort_values('Percent_Outliers', ascending=False)
    return count_outliers

count_outliers = outliers(df=data, features=features)
count_outliers
# Out:
#                              Feature  Num_Outliers  Percent_Outliers  \
# 15                  PRC_FULL_PAYMENT          3047          0.340447
# 1                  BALANCE_FREQUENCY          1716          0.191732
# 16                            TENURE          1366          0.152626
# 14                  MINIMUM_PAYMENTS          1165          0.130168
# 5                       CASH_ADVANCE          1000          0.111732
# 13                          PAYMENTS           877          0.097989
# 3                   ONEOFF_PURCHASES           859          0.095978
# 2                          PURCHASES           624          0.069721
# 10                  CASH_ADVANCE_TRX           611          0.068268
# 11                     PURCHASES_TRX           529          0.059106
# 4             INSTALLMENTS_PURCHASES           442          0.049385
# 0                            BALANCE           412          0.046034
# 12                      CREDIT_LIMIT           248          0.027709
# 9             CASH_ADVANCE_FREQUENCY           133          0.014860
# 7         ONEOFF_PURCHASES_FREQUENCY             0          0.000000
# 6                PURCHASES_FREQUENCY             0          0.000000
# 8   PURCHASES_INSTALLMENTS_FREQUENCY             0          0.000000
#
#           IQR  Total_Rows
# 15   0.000000        8950
# 1    0.057191        8950
# 16   0.000000        8950
# 14   9.893364        8950
# 5   21.259010        8950
# 13  17.427047        8950
# 3   16.257321        8950
# 2   20.237915        8950
# 10   1.414214        8950
# 11   2.464102        8950
# 4   16.855578        8950
# 0   26.567573        8950
# 12  30.710678        8950
# 9    0.353553        8950
# 7    0.408249        8950
# 6    0.577351        8950
# 8    0.707107        8950

# %%
for i in features:
    sns.boxplot(data[i])
    plt.show()

# %% [markdown]
# ### KOLERASYON

# %%
#Verilerin birbiriyle fazla ilişkili olması, analizimizi saptırabilir. 
#Bu yüzden korelasyonuna bakıyoruz.
#Koyu bölgeler değişkenlerin birbiriyle daha fazla ilişkili olduğunu gösteriyor.

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#Standard Scaler ile verisetinin normalizasyonunu gerçekleştiririz
#Ayrıca daha önce düşürdüğümüz sütunu normalizasyonun yapıldığı sütunlarla birleştiririz

# %%
from sklearn.preprocessing import StandardScaler
# Scale the features
X = data[features]
X_scaled = pd.DataFrame(StandardScaler().fit_transform(X), columns=X.columns, index=X.index)
df_scaled = pd.concat([df['CUST_ID'], X_scaled], axis=1)

# %%
df_scaled
# Out:
#      CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001 -1.078055          -0.097126  -0.596901         -0.724371
# 1     C10002  1.053619           0.190539  -1.042337         -0.724371
# 2     C10003  0.771680           0.464146   0.225748          0.686250
# 3     C10004  0.384093          -0.725092   0.723342          1.239775
# 4     C10005 -0.135254           0.464146  -0.859918         -0.521447
# ...      ...       ...                ...        ...               ...
# 8945  C19186 -1.122962           0.464146  -0.264216         -0.724371
# 8946  C19187 -1.163649           0.464146  -0.252438         -0.724371
# 8947  C19188 -1.144226          -0.048112  -0.494319         -0.724371
# 8948  C19189 -1.193861          -0.048112  -1.042337         -0.724371
# 8949  C19190 -0.529782          -0.614723   0.465556          0.953013
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                  -0.209397     -0.732851            -0.455097
# 1                  -0.837899      2.447876            -1.511903
# 2                  -0.837899     -0.732851             1.076731
# 3                  -0.837899     -0.164399            -0.764630
# 4                  -0.837899     -0.732851            -0.764630
# ...                      ...           ...                  ...
# 8945                0.260016     -0.732851             1.076731
# 8946                0.276635     -0.732851             1.076731
# 8947               -0.064656     -0.732851             0.851185
# 8948               -0.837899     -0.493255            -1.511903
# 8949               -0.837899     -0.286215             0.601708
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                      -0.881832                         -0.350094
# 1                      -0.881832                         -1.040015
# 2                       2.081316                         -1.040015
# 3                      -0.026447                         -1.040015
# 4                      -0.026447                         -1.040015
# ...                          ...                               ...
# 8945                   -0.881832                          1.141709
# 8946                   -0.881832                          1.141709
# 8947                   -0.881832                          0.911379
# 8948                   -0.881832                         -1.040015
# 8949                    1.537568                         -1.040015
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                  -0.861347         -0.772904      -0.578392     -1.212754
# 1                   0.933739          0.629493      -1.136616      0.855567
# 2                  -0.861347         -0.772904       0.230748      0.972272
# 3                   0.175044         -0.071706      -0.741892      0.972272
# 4                  -0.861347         -0.772904      -0.741892     -1.092802
# ...                      ...               ...            ...           ...
# 8945               -0.861347         -0.772904      -0.169743     -1.212754
# 8946               -0.861347         -0.772904      -0.169743     -1.212754
# 8947               -0.861347         -0.772904      -0.253986     -1.212754
# 8948                0.604336          0.218740      -1.136616     -1.580851
# 8949                1.211439          0.218740       0.756414     -1.092802
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# 0    -0.885440         -0.644743         -0.636182  0.353481
# 1     1.274046          0.545992          0.788874  0.353481
# 2    -0.420372          0.107983         -0.636182  0.353481
# 3    -1.500837         -0.311339         -0.636182  0.353481
# 4    -0.372564         -0.426655         -0.636182  0.353481
# ...        ...               ...               ...       ...
# 8945 -0.719154         -0.918866          1.501403 -4.276127
# 8946 -0.781326         -0.311339         -0.636182 -4.276127
# 8947 -1.110302         -0.800187          0.875319 -4.276127
# 8948 -1.186802         -0.891844          0.875319 -4.276127
# 8949 -1.156541         -0.782114         -0.636182 -4.276127
#
# [8950 rows x 18 columns]

# %%
df_scaled[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   float64
#  11  PURCHASES_TRX                     8950 non-null   float64
#  12  CREDIT_LIMIT                      8950 non-null   float64
#  13  PAYMENTS                          8950 non-null   float64
#  14  MINIMUM_PAYMENTS                  8950 non-null   float64
#  15  PRC_FULL_PAYMENT                  8950 non-null   float64
#  16  TENURE                            8950 non-null   float64
# dtypes: float64(17)
# memory usage: 1.2 MB

# %%
#df_scaled içindeki verilerin sırasıyla ortalamasına,ortanca değerine,minimum ve maximum değerlerine bakalım

# %%
(df_scaled[features].describe().transpose()
     [['mean', '50%', 'min', 'max']]
     .rename(columns={'50%': 'median'})
     .style.background_gradient(cmap = "twilight_shifted"))
# Out:
# <style type="text/css">
# #T_63290_row0_col0, #T_63290_row9_col0 {
#   background-color: #65194c;
#   color: #f1f1f1;
# }
# #T_63290_row0_col1, #T_63290_row11_col1 {
#   background-color: #d4beaf;
#   color: #000000;
# }
# #T_63290_row0_col2 {
#   background-color: #842550;
#   color: #f1f1f1;
# }
# #T_63290_row0_col3 {
#   background-color: #6c8ebf;
#   color: #f1f1f1;
# }
# #T_63290_row1_col0 {
#   background-color: #b35752;
#   color: #f1f1f1;
# }
# #T_63290_row1_col1, #T_63290_row12_col0, #T_63290_row14_col3, #T_63290_row15_col2 {
#   background-color: #2f1436;
#   color: #f1f1f1;
# }
# #T_63290_row1_col2, #T_63290_row9_col1, #T_63290_row16_col0, #T_63290_row16_col3 {
#   background-color: #301437;
#   color: #f1f1f1;
# }
# #T_63290_row1_col3 {
#   background-color: #32123a;
#   color: #f1f1f1;
# }
# #T_63290_row2_col0 {
#   background-color: #491341;
#   color: #f1f1f1;
# }
# #T_63290_row2_col1 {
#   background-color: #e1d7dc;
#   color: #000000;
# }
# #T_63290_row2_col2, #T_63290_row8_col2 {
#   background-color: #591648;
#   color: #f1f1f1;
# }
# #T_63290_row2_col3 {
#   background-color: #cda78e;
#   color: #000000;
# }
# #T_63290_row3_col0 {
#   background-color: #721d4f;
#   color: #f1f1f1;
# }
# #T_63290_row3_col1 {
#   background-color: #7fa5c3;
#   color: #f1f1f1;
# }
# #T_63290_row3_col2 {
#   background-color: #351138;
#   color: #f1f1f1;
# }
# #T_63290_row3_col3 {
#   background-color: #c89275;
#   color: #f1f1f1;
# }
# #T_63290_row4_col0, #T_63290_row6_col2 {
#   background-color: #963350;
#   color: #f1f1f1;
# }
# #T_63290_row4_col1 {
#   background-color: #dad8df;
#   color: #000000;
# }
# #T_63290_row4_col2 {
#   background-color: #3f123d;
#   color: #f1f1f1;
# }
# #T_63290_row4_col3 {
#   background-color: #d0b09b;
#   color: #000000;
# }
# #T_63290_row5_col0 {
#   background-color: #4e1443;
#   color: #f1f1f1;
# }
# #T_63290_row5_col1 {
#   background-color: #531d7a;
#   color: #f1f1f1;
# }
# #T_63290_row5_col2 {
#   background-color: #361138;
#   color: #f1f1f1;
# }
# #T_63290_row5_col3 {
#   background-color: #ded3d3;
#   color: #000000;
# }
# #T_63290_row6_col0 {
#   background-color: #c0755e;
#   color: #f1f1f1;
# }
# #T_63290_row6_col1 {
#   background-color: #6b1b4d;
#   color: #f1f1f1;
# }
# #T_63290_row6_col3 {
#   background-color: #411254;
#   color: #f1f1f1;
# }
# #T_63290_row7_col0 {
#   background-color: #933050;
#   color: #f1f1f1;
# }
# #T_63290_row7_col1 {
#   background-color: #cba085;
#   color: #f1f1f1;
# }
# #T_63290_row7_col2, #T_63290_row8_col0 {
#   background-color: #44123f;
#   color: #f1f1f1;
# }
# #T_63290_row7_col3 {
#   background-color: #59298e;
#   color: #f1f1f1;
# }
# #T_63290_row8_col1 {
#   background-color: #d0b29c;
#   color: #000000;
# }
# #T_63290_row8_col3 {
#   background-color: #491564;
#   color: #f1f1f1;
# }
# #T_63290_row9_col2 {
#   background-color: #42123e;
#   color: #f1f1f1;
# }
# #T_63290_row9_col3 {
#   background-color: #6068b6;
#   color: #f1f1f1;
# }
# #T_63290_row10_col0 {
#   background-color: #983550;
#   color: #f1f1f1;
# }
# #T_63290_row10_col1 {
#   background-color: #471461;
#   color: #f1f1f1;
# }
# #T_63290_row10_col2 {
#   background-color: #39113a;
#   color: #f1f1f1;
# }
# #T_63290_row10_col3, #T_63290_row13_col1 {
#   background-color: #d9d8de;
#   color: #000000;
# }
# #T_63290_row11_col0 {
#   background-color: #a64550;
#   color: #f1f1f1;
# }
# #T_63290_row11_col2 {
#   background-color: #67194c;
#   color: #f1f1f1;
# }
# #T_63290_row11_col3 {
#   background-color: #b9c9d0;
#   color: #000000;
# }
# #T_63290_row12_col1 {
#   background-color: #bccbd1;
#   color: #000000;
# }
# #T_63290_row12_col2 {
#   background-color: #c58468;
#   color: #f1f1f1;
# }
# #T_63290_row12_col3 {
#   background-color: #6a8bbf;
#   color: #f1f1f1;
# }
# #T_63290_row13_col0 {
#   background-color: #7b2150;
#   color: #f1f1f1;
# }
# #T_63290_row13_col2 {
#   background-color: #953250;
#   color: #f1f1f1;
# }
# #T_63290_row13_col3 {
#   background-color: #d8c7be;
#   color: #000000;
# }
# #T_63290_row14_col0 {
#   background-color: #8f2d50;
#   color: #f1f1f1;
# }
# #T_63290_row14_col1 {
#   background-color: #b2c6ce;
#   color: #000000;
# }
# #T_63290_row14_col2 {
#   background-color: #7e2250;
#   color: #f1f1f1;
# }
# #T_63290_row15_col0 {
#   background-color: #4f1444;
#   color: #f1f1f1;
# }
# #T_63290_row15_col1 {
#   background-color: #5e46a6;
#   color: #f1f1f1;
# }
# #T_63290_row15_col3 {
#   background-color: #5c369b;
#   color: #f1f1f1;
# }
# #T_63290_row16_col1 {
#   background-color: #581647;
#   color: #f1f1f1;
# }
# #T_63290_row16_col2 {
#   background-color: #616fb9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_63290_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mean</th>
#       <th class="col_heading level0 col1" >median</th>
#       <th class="col_heading level0 col2" >min</th>
#       <th class="col_heading level0 col3" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63290_level0_row0" class="row_heading level0 row0" >BALANCE</th>
#       <td id="T_63290_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_63290_row0_col1" class="data row0 col1" >-0.094595</td>
#       <td id="T_63290_row0_col2" class="data row0 col2" >-1.349652</td>
#       <td id="T_63290_row0_col3" class="data row0 col3" >4.510781</td>
#     </tr>
#     <tr>
#       <th id="T_63290_level0_row1" class="row_heading level0 row1" >BALANCE_FREQUENCY</th>
#       <td id="T_63290_row1_col0" class="data row1 col0" >-0.000000</td>
#       <td id="T_63290_row1_col1" class="data row1 col1" >0.464146</td>
#       <td id="T_63290_row1_col2" class="data row1 col2" >-5.415146</td>
#       <td id="T_63290_row1_col3" class="data row1 col3" >0.464146</td>
#     </tr>
#     <tr>
#       <th id="T_63290_level0_row2" class="row_heading level0 row2" >PURCHASES</th>
#       <td id="T_63290_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_63290_row2_col1" class="data row2 col1" >-0.175509</td>
#       <td id="T_63290_row2_col2" class="data row2 col2" >-1.042337</td>
#       <td id="T_63290_row2_col3" class="data row2 col3" >9.056799</td>
#     </tr>
#     <tr>
#       <th id="T_63290_level0_row3" class="row_heading level0 row3" >ONEOFF_PURCHASES</th>
#       <td id="T_63290_row3_col0" class="data row3 col0" >-0.000000</td>
#       <td id="T_63290_row3_col1" class="data row3 col1" >-0.411645</td>
#       <td id="T_63290_row3_col2" class="data row3 col2" >-0.724371</td>
#       <td id="T_63290_row3_col3" class="data row3 col3" >9.517909</td>
#     </tr>
#     <tr>
#       <th id="T_63290_level0_row4" class="row_heading level0 row4" >INSTALLMENTS_PURCHASES</th>
#       <td id="T_63290_row4_col0" class="data row4 col0" >-0.000000</td>
#       <td id="T_63290_row4_col1" class="data row4 col1" >-0.230845</td>
#       <td id="T_63290_row4_col2" class="data row4 col2" >-0.837899</td>
#       <td id="T_63290_row4_col3" class="data row4 col3" >8.814248</td>
#     </tr>
#     <tr>
#       <th id="T_63290_level0_row5" class="row_heading level0 row5" >CASH_ADVANCE</th>
#       <td id="T_63290_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_63290_row5_col1" class="data row5 col1" >-0.732851</td>
#       <td id="T_63290_row5_col2" class="data row5 col2" >-0.732851</td>
#       <td id="T_63290_row5_col3" class="data row5 col3" >7.870471</td>
#     </tr>
#     <tr>
#       <th id="T_63290_level0_row6" class="row_heading level0 row6" >PURCHASES_FREQUENCY</th>
#       <td id="T_63290_row6_col0" class="data row6 col0" >-0.000000</td>
#       <td id="T_63290_row6_col1" class="data row6 col1" >0.318537</td>
#       <td id="T_63290_row6_col2" class="data row6 col2" >-1.511903</td>
#       <td id="T_63290_row6_col3" class="data row6 col3" >1.076731</td>
#     </tr>
#     <tr>
#       <th id="T_63290_level0_row7" class="row_heading level0 row7" >ONEOFF_PURCHASES_FREQUENCY</th>
#       <td id="T_63290_row7_col0" class="data row7 col0" >-0.000000</td>
#       <td id="T_63290_row7_col1" class="data row7 col1" >-0.026447</td>
#       <td id="T_63290_row7_col2" class="data row7 col2" >-0.881832</td>
#       <td id="T_63290_row7_col3" class="data row7 col3" >2.081316</td>
#     </tr>
#     <tr>
#       <th id="T_63290_level0_row8" class="row_heading level0 row8" >PURCHASES_INSTALLMENTS_FREQUENCY</th>
#       <td id="T_63290_row8_col0" class="data row8 col0" >0.000000</td>
#       <td id="T_63290_row8_col1" class="data row8 col1" >-0.064317</td>
#       <td id="T_63290_row8_col

# %% [markdown]
# ### BOOTSTRAP

# %%
#Bootstrap, bir değişkenin popülasyon ortalamasını tahmin etmek için kullanılan bir tekniktir. Bunu, verileri değiştirerek tekrar tekrar örnekleyerek ve her örnek için ortalamayı kaydederek yapar. 
#Tahmini popülasyon ortalaması, tüm örnek ortalamaların ortalamasıdır.

# %%
# Bootstrap sampling
samples = 1000
est_popu_means = {}
boot = []
for a in features:
    for b in range(samples):
        c = df[a].sample(frac = 0.33, random_state = 1).mean()
        boot.append(c)
    p_mean = sum(boot)/len(boot)
    est_popu_means[a] = p_mean
    boot.clear()

# Mean of each feature in the dataset
sampling_mean = []
for i in features:
    x = df[i].mean()
    sampling_mean.append(x)

df_means = pd.DataFrame({'Feature': list(est_popu_means.keys())
                       , 'Bootstrap_Mean': list(est_popu_means.values())
                       , 'Mean_in_dataset': sampling_mean})

df_means
# Out:
#                              Feature  Bootstrap_Mean  Mean_in_dataset
# 0                            BALANCE     1544.925802      1564.474828
# 1                  BALANCE_FREQUENCY        0.880153         0.877271
# 2                          PURCHASES     1029.234242      1003.204834
# 3                   ONEOFF_PURCHASES      614.426114       592.437371
# 4             INSTALLMENTS_PURCHASES      414.974506       411.067645
# 5                       CASH_ADVANCE      939.023397       978.871112
# 6                PURCHASES_FREQUENCY        0.496370         0.490351
# 7         ONEOFF_PURCHASES_FREQUENCY        0.198057         0.202458
# 8   PURCHASES_INSTALLMENTS_FREQUENCY        0.370166         0.364437
# 9             CASH_ADVANCE_FREQUENCY        0.132016         0.135144
# 10                  CASH_ADVANCE_TRX        3.113067         3.248827
# 11                     PURCHASES_TRX       14.807718        14.709832
# 12                      CREDIT_LIMIT     4538.437524      4494.282473
# 13                          PAYMENTS     1742.011384      1733.143852
# 14                  MINIMUM_PAYMENTS      887.718778       844.906767
# 15                  PRC_FULL_PAYMENT        0.162768         0.153715
# 16                            TENURE       11.515911        11.517318

# %%
#Her özelliğin dağılımını görselleştirmek için bir histogram kullanalım.
## Bootstrap sampling tahmini popülasyon ortalamasını, belirtmek için histograma dikey bir çizgi ekleyelim

# %%
for i in features:
    boot_mean = df_means.loc[df_means['Feature'] == i, 'Bootstrap_Mean'].iloc[0]
    print(i)
    print('Bootstrap mean:', boot_mean)
    sns.histplot(df[i])
    plt.axvline(boot_mean, color = 'red')
    plt.show()
# Out:
# BALANCE
# Bootstrap mean: 1544.9258020701038
# BALANCE_FREQUENCY
# Bootstrap mean: 0.8801531983750754
# PURCHASES
# Bootstrap mean: 1029.2342417061789
# ONEOFF_PURCHASES
# Bootstrap mean: 614.4261137440737
# INSTALLMENTS_PURCHASES
# Bootstrap mean: 414.9745057549034
# CASH_ADVANCE
# Bootstrap mean: 939.0233965822512
# PURCHASES_FREQUENCY
# Bootstrap mean: 0.49637017907922376
# ONEOFF_PURCHASES_FREQUENCY
# Bootstrap mean: 0.19805704468517663
# PURCHASES_INSTALLMENTS_FREQUENCY
# Bootstrap mean: 0.37016616418416426
# CASH_ADVANCE_FREQUENCY
# Bootstrap mean: 0.13201607278266547
# CASH_ADVANCE_TRX
# Bootstrap mean: 3.113067027758926
# PURCHASES_TRX
# Bootstrap mean: 14.807718348002306
# CREDIT_LIMIT
# Bootstrap mean: 4538.437523508847
# PAYMENTS
# Bootstrap mean: 1742.0113839796504
# MINIMUM_PAYMENTS
# Bootstrap mean: 887.718778012875
# PRC_FULL_PAYMENT
# Bootstrap mean: 0.16276787542315654
# TENURE
# Bootstrap mean: 11.515910629654666

# %%
#Özellikler normal dağılmadığından spearman correlation  kullanırız. Spearman correlation , değişkenler arasındaki ilişkiyi ölçmek için sıraları kullanır ve verilerin normal olarak dağıtılmasını gerektirmez.

# %%
spearman_corr = round(df_scaled[features].corr(method = 'spearman'),2)
spearman_corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_9b83f_row0_col0, #T_9b83f_row1_col1, #T_9b83f_row2_col2, #T_9b83f_row3_col3, #T_9b83f_row4_col4, #T_9b83f_row5_col5, #T_9b83f_row6_col6, #T_9b83f_row7_col7, #T_9b83f_row8_col8, #T_9b83f_row9_col9, #T_9b83f_row10_col10, #T_9b83f_row11_col11, #T_9b83f_row12_col12, #T_9b83f_row13_col13, #T_9b83f_row14_col14, #T_9b83f_row15_col15, #T_9b83f_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9b83f_row0_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_9b83f_row0_col2, #T_9b83f_row3_col12 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_9b83f_row0_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_9b83f_row0_col4, #T_9b83f_row0_col6, #T_9b83f_row3_col16, #T_9b83f_row6_col16 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_9b83f_row0_col5 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_9b83f_row0_col7, #T_9b83f_row14_col13 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_9b83f_row0_col8, #T_9b83f_row11_col12 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_9b83f_row0_col9 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_9b83f_row0_col10, #T_9b83f_row1_col0, #T_9b83f_row9_col0 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_9b83f_row0_col11, #T_9b83f_row3_col1, #T_9b83f_row4_col1, #T_9b83f_row8_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_9b83f_row0_col12, #T_9b83f_row3_col15, #T_9b83f_row7_col14, #T_9b83f_row12_col4, #T_9b83f_row16_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_9b83f_row0_col13, #T_9b83f_row7_col8, #T_9b83f_row16_col8 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_9b83f_row0_col14, #T_9b83f_row14_col0 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_9b83f_row0_col15, #T_9b83f_row5_col3, #T_9b83f_row5_col6, #T_9b83f_row5_col7, #T_9b83f_row5_col8, #T_9b83f_row5_col11, #T_9b83f_row6_col5, #T_9b83f_row6_col9, #T_9b83f_row6_col10, #T_9b83f_row8_col13, #T_9b83f_row9_col2, #T_9b83f_row9_col3, #T_9b83f_row9_col4, #T_9b83f_row9_col6, #T_9b83f_row9_col8, #T_9b83f_row9_col11, #T_9b83f_row9_col16, #T_9b83f_row10_col3, #T_9b83f_row10_col6, #T_9b83f_row14_col15, #T_9b83f_row15_col0, #T_9b83f_row15_col1, #T_9b83f_row15_col12, #T_9b83f_row15_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9b83f_row0_col16, #T_9b83f_row7_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_9b83f_row1_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_9b83f_row1_col3, #T_9b83f_row4_col0, #T_9b83f_row5_col1, #T_9b83f_row7_col12, #T_9b83f_row8_col14, #T_9b83f_row11_col16, #T_9b83f_row12_col16 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_9b83f_row1_col4, #T_9b83f_row7_col15 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_9b83f_row1_col5, #T_9b83f_row7_col4, #T_9b83f_row12_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_9b83f_row1_col6, #T_9b83f_row13_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_9b83f_row1_col7 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_9b83f_row1_col8 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_9b83f_row1_col9, #T_9b83f_row1_col10 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_9b83f_row1_col11 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_9b83f_row1_col12, #T_9b83f_row9_col13 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_9b83f_row1_col13, #T_9b83f_row4_col12, #T_9b83f_row10_col13, #T_9b83f_row16_col13 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9b83f_row1_col14, #T_9b83f_row10_col14, #T_9b83f_row14_col5 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_9b83f_row1_col15, #T_9b83f_row14_col8, #T_9b83f_row15_col7 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_9b83f_row1_col16, #T_9b83f_row2_col14, #T_9b83f_row4_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_9b83f_row2_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_9b83f_row2_col1, #T_9b83f_row8_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_9b83f_row2_col3, #T_9b83f_row2_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_9b83f_row2_col5, #T_9b83f_row2_col10, #T_9b83f_row8_col5, #T_9b83f_row8_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9b83f_row2_col6, #T_9b83f_row4_col6 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_9b83f_row2_col7 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_9b83f_row2_col8 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_9b83f_row2_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_9b83f_row2_col11 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_9b83f_row2_col12, #T_9b83f_row14_col12 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_9b83f_row2_col13 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_9b83f_row2_col15 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_9b83f_row2_col16, #T_9b83f_row7_col13, #T_9b83f_row8_col0, #T_9b83f_row14_col16, #T_9b83f_row16_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_9b83f_row3_col0, #T_9b83f_row12_col11 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_9b83f_row3_col2 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_9b83f_row3_col4 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_9b83f_row3_col5, #T_9b83f_row3_col9, #T_9b83f_row3_col10, #T_9b83f_row7_col9, #T_9b83f_row7_col16 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_9b83f_row3_col6 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_9b83f_row3_col7, #T_9b83f_row5_col9, #T_9b83f_row7_col3, #T_9b83f_row9_col5 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_9b83f_row3_col8, #T_9b83f_row13_col8 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_9b83f_row3_col11, #T_9b83f_row5_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_9b83f_row3_col13, #T_9b83f_row14_col2 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_9b83f_row3_col14, #T_9b83f_row12_col9, #T_9b83f_row16_col0, #T_9b83f_row16_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_9b83f_row4_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_9b83f_row4_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_9b83f_row4_col5, #T_9b83f_row4_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_9b83f_row4_col8, #T_9b83f_row6_col11, #T_9b83f_row8_col4, #T_9b83f_row11_col6 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_9b83f_row4_col9, #T_9b83f_row6_col13, #T_9b83f_row8_col10 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_9b83f_row4_col11, #T_9b83f_row6_col4, #T_9b83f_row8_col11 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_9b83f_row4_col13, #T_9b83f_row10_col15 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_9b83f_row4_col14, #T_9b83f_row7_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_9b83f_row4_col15 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_9b83f_row4_col16, #T_9b83f_row16_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_9b83f_row5_col2, #T_9b83f_row5_col4, #T_9b83f_row10_col2, #T_9b83f_row10_col4, #T_9b83f_row10_col8, #T_9b83f_row10_col11 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_9b83f_row5_col10, #T_9b83f_row10_col5 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_9b83f_row5_col12, #T_9b83f_row5_col15 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_9b83f_row5_col13 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_9b83f_row5_col14 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_9b83f_row5_col16, #T_9b83f_row10_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_9b83f_row6_col0, #T_9b83f_row14_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_9b83f_row6_col1, #T_9b83f_row11_col1 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_9b83f_row6_col2 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_9b83f_row6_col3, #T_9b83f_row15_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_9b83f_row6_col7 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_9b83f_row6_col8 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_9b83f_row6_col12, #T_9b83f_row10_col12, #T_9b83f_row15_col13 {
#   backgro

# %% [markdown]
# ### K-Means Clustering

# %%
#K-kümeleme anlamına gelir
#Kümeler müşteri segmentleri olacaktır.

#En uygun küme sayısını bulacağız
#Optimal küme sayısını seçmek için dirsek yöntemini kullanalım. KElbowVisualizer kütüphanesi, bir dizi kümede döngü yapar ve distorsiyonu kaydeder (her gözlem vektörü ile onun hakim olan merkez noktası arasındaki kare mesafelerin toplamı). Ardından, bozulmayı küme sayısına karşı çizer ve grafikte dirsek gibi görünen noktayı kullanarak optimal küme sayısını tanımlar.

# %%
#K-Means Clutting

# %%
#Optimal küme sayımızın 4 olduğu görülmektedir.

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
X = df_scaled[features]
kmeans = KMeans(random_state=1)
kmeans_vis = KElbowVisualizer(kmeans, k=(1,15), metric='distortion', timings=False).fit(X)
print('Optimal number of clusters:', kmeans_vis.elbow_value_)
# Out:
# Optimal number of clusters: 4

# %%
# Cluster the customers using the optimal number of clusters
df_scaled['CLUSTERS'] = KMeans(n_clusters=kmeans_vis.elbow_value_, random_state=1).fit_predict(X)

# Count the number of customers in each cluster
count_clusters = df_scaled.groupby('CLUSTERS').agg({'CUST_ID': 'nunique'})
customers = df_scaled['CUST_ID'].nunique()
count_clusters['Percent_of_Customers'] = count_clusters['CUST_ID']/customers
count_clusters
# Out:
#           CUST_ID  Percent_of_Customers
# CLUSTERS
# 0            2552              0.285140
# 1            3826              0.427486
# 2            1468              0.164022
# 3            1104              0.123352

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

ss= StandardScaler()
df= ss.fit_transform(data)

pca= PCA()
pca.fit(data)
# Out:
# PCA()

# %%
plt.plot(pca.explained_variance_ratio_.cumsum())

# %%
pca= PCA(n_components=6)
X= pca.fit_transform(data)

# %%
df
# Out:
# array([[-1.0780545 , -0.09712559, -0.59690132, ..., -0.64474346,
#         -0.63618182,  0.35348056],
#        [ 1.05361908,  0.19053935, -1.0423371 , ...,  0.54599164,
#          0.78887411,  0.35348056],
#        [ 0.77167992,  0.46414608,  0.22574803, ...,  0.1079828 ,
#         -0.63618182,  0.35348056],
#        ...,
#        [-1.14422589, -0.04811222, -0.49431949, ..., -0.80018722,
#          0.87531901, -4.27612743],
#        [-1.19386072, -0.04811222, -1.0423371 , ..., -0.89184415,
#          0.87531901, -4.27612743],
#        [-0.52978249, -0.61472285,  0.46555636, ..., -0.78211369,
#         -0.63618182, -4.27612743]])

# %%
kmeans= KMeans(n_clusters=kmeans_vis.elbow_value_, n_init=10, init= 'k-means++', algorithm='full', max_iter=300)
kmeans.fit(X)
labels= kmeans.labels_

# %%
df
# Out:
# array([[-1.0780545 , -0.09712559, -0.59690132, ..., -0.64474346,
#         -0.63618182,  0.35348056],
#        [ 1.05361908,  0.19053935, -1.0423371 , ...,  0.54599164,
#          0.78887411,  0.35348056],
#        [ 0.77167992,  0.46414608,  0.22574803, ...,  0.1079828 ,
#         -0.63618182,  0.35348056],
#        ...,
#        [-1.14422589, -0.04811222, -0.49431949, ..., -0.80018722,
#          0.87531901, -4.27612743],
#        [-1.19386072, -0.04811222, -1.0423371 , ..., -0.89184415,
#          0.87531901, -4.27612743],
#        [-0.52978249, -0.61472285,  0.46555636, ..., -0.78211369,
#         -0.63618182, -4.27612743]])

# %%
pca= PCA(n_components=2)
X2= pca.fit_transform(df)

# %%
X2
# Out:
# array([[-0.89368741, -2.4694229 ],
#        [-2.99580332,  2.03198255],
#        [ 1.19249038,  0.38666621],
#        ...,
#        [ 0.09522873, -3.05690433],
#        [-2.85831224, -2.50503783],
#        [-0.1704341 , -0.53629679]])

# %%
pca_df = pd.DataFrame(data=X2, columns=['pca1','pca2'])
pca_df['labels']= labels
pca_df.head()
# Out:
#        pca1      pca2  labels
# 0 -0.893687 -2.469423       1
# 1 -2.995804  2.031980       2
# 2  1.192490  0.386666       0
# 3 -0.771432  0.016180       0
# 4 -1.271211 -1.577259       1

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x='pca1', y='pca2', hue='labels', data=pca_df, palette='bright')

# %%
kmeans= KMeans(n_clusters=3, n_init=10, init= 'k-means++', algorithm='full', max_iter=300)
kmeans.fit(X)
labels= kmeans.labels_

# %%
pca= PCA(n_components=2)
X2= pca.fit_transform(df)

# %%
pca_df = pd.DataFrame(data=X2, columns=['pca1','pca2'])
pca_df['labels']= labels
pca_df.head()
# Out:
#        pca1      pca2  labels
# 0 -0.893687 -2.469423       0
# 1 -2.995803  2.031983       1
# 2  1.192490  0.386666       0
# 3 -0.771431  0.016181       0
# 4 -1.271211 -1.577259       0

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x='pca1', y='pca2', hue='labels', data=pca_df, palette='bright')

# %%
#Bunları kullanımımıza göre 3 veya 5 küme kullanarak gruplayabiliriz

# %%
# Plot the average feature value for each cluster
describe_clusters = df_scaled.groupby('CLUSTERS').mean()

for i in features:
    sns.barplot(x = describe_clusters.index
               , y = i
               , data = describe_clusters)
    plt.title('Mean ' + str(i) + ' by Cluster')
    plt.show()
